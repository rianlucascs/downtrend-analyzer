# %%
from Scripts.dowtrend import Dowtrend
from Scripts.graficos import Graficos

data_dos_dados = '05/11/24'

# %% [markdown]
# # Top 10 Ações com Maior Desvalorização Mensal

# %%
# semanal, quinzenal, mensal, trimestral, anual
period = 'mensal'
type_amostra = 'empresas_listadas'

dowtrend = Dowtrend(type_amostra=type_amostra)
data = dowtrend.read_data('DataFrame')
dowtrend_data = dowtrend.obter_maximos(data, period, 'DESVALORIZAÇÃO')
dowtrend_data
# Out:
#        semanal  quinzenal  mensal  trimestral  anual
# AESB3   -28.76     -30.45  -29.73      -29.73 -33.44
# SRNA3    -5.59     -12.00  -12.53      -11.03 -28.89
# GSHP3   -11.76     -11.76  -11.76      -21.05 -50.00
# JFEN3    -8.00     -17.86  -11.54      -23.33 -89.30
# FIEI3    -9.57      -9.57   -9.49       20.23 -13.33
# HBTS5    -3.30      -3.30   -9.34      -18.28 -40.79
# HETA4    -2.20     -10.90   -9.21        2.64  -2.20
# LUXM4     4.26      -9.49   -8.90      -10.72 -20.72
# AMER3    -2.30     -12.37   -8.11      -26.88 -96.26
# SHOW3    -2.22      -5.38   -7.37      -13.73 -58.29

# %%
Graficos(dowtrend).grafico2(dowtrend_data[[period]], period)

# %%
Graficos(dowtrend).grafico1('AESB3')

# %% [markdown]
# # Top 10 Ações com Maior Valorização Mensal

# %%
# semanal, quinzenal, mensal, trimestral, anual
period = 'mensal'
type_amostra = 'empresas_listadas'

dowtrend = Dowtrend(type_amostra=type_amostra)
data = dowtrend.read_data('DataFrame')
dowtrend_data = dowtrend.obter_maximos(data, period, 'VALORIZAÇÃO')
dowtrend_data
# Out:
#         semanal  quinzenal  mensal  trimestral  anual
# ELMD3     47.77      47.77   43.98       59.34  69.11
# VVEO3     31.88      41.45   31.88       50.00 -79.89
# BKWB39     7.09       7.09   26.82       26.82    NaN
# KRSA3     10.34       9.75   16.79       26.33 -52.38
# PGMN3     18.02      18.44   16.38       27.97  -6.54
# TOTS3     11.21      17.88   15.35       20.52   3.04
# PSVM11    14.80      -0.69   14.80       14.80   4.55
# QUAL3     12.55      12.55   14.54       16.07 -23.53
# AERI3     16.58      11.29   14.33       15.64 -60.56
# MWET4     12.09      31.70   12.09       41.34  78.31

# %%
Graficos(dowtrend).grafico2(dowtrend_data[[period]], period)

# %%
Graficos(dowtrend).grafico1('ELMD3')

# %% [markdown]
# # Top 10 Ações com Maior Desvalorização Mensal do Índice IDIV

# %%
# semanal, quinzenal, mensal, trimestral, anual
period = 'mensal'
type_amostra = 'indice:IDIV'

dowtrend = Dowtrend(type_amostra=type_amostra)
data = dowtrend.read_data('DataFrame')
dowtrend_data = dowtrend.obter_maximos(data, period, 'DESVALORIZAÇÃO')
dowtrend_data
# Out:
#         semanal  quinzenal  mensal  trimestral  anual
# SAPR4      0.38       0.38   -3.79      -10.57  -4.94
# CURY3     -1.67      -6.14   -3.60        7.00  42.17
# BBDC4     -1.14      -1.14   -2.93       -3.69 -13.51
# TIMS3     -2.36      -4.84   -2.71      -13.88  -5.58
# PETR3     -0.39      -3.27   -2.33       -2.85  10.38
# BBDC3     -0.42      -5.84   -2.14       -3.30 -13.41
# FLRY3      2.04      -4.09   -1.96       -5.83 -16.89
# PETR4     -0.08      -1.99   -1.45       -1.72   7.88
# DIRR3      0.62      -1.63   -1.41        1.95  47.89
# SANB11     0.26       0.26   -1.21       -4.02 -12.00

# %%
Graficos(dowtrend).grafico2(dowtrend_data[[period]], period)

# %%
Graficos(dowtrend).grafico1('SAPR4')

# %% [markdown]
# # Top 10 Ações com Maior Valorização Mensal do Índice IDIV

# %%
# semanal, quinzenal, mensal, trimestral, anual
period = 'mensal'
type_amostra = 'indice:IDIV'

dowtrend = Dowtrend(type_amostra=type_amostra)
data = dowtrend.read_data('DataFrame')
dowtrend_data = dowtrend.obter_maximos(data, period, 'VALORIZAÇÃO')
dowtrend_data
# Out:
#         semanal  quinzenal  mensal  trimestral  anual
# TGMA3      7.46       7.50    6.88       17.72  20.27
# TASA4      8.20       0.91    6.70       -3.56 -32.34
# KLBN11     5.14       6.05    5.94        5.79  13.51
# FESA4      7.89       6.59    4.89        3.26 -30.83
# KEPL3      7.38       4.63    4.63        6.63   1.13
# JHSF3      6.96       5.51    4.56       13.81 -11.10
# CSNA3      5.49       6.96    4.42       -4.65 -34.09
# ITSA4      5.23       4.05    4.24       -0.09  12.79
# UNIP6      4.55       1.16    3.24       -1.03 -33.34
# POMO4      4.81      -1.47    3.07        9.69  31.06

# %%
Graficos(dowtrend).grafico2(dowtrend_data[[period]], period)

# %%
Graficos(dowtrend).grafico1('TGMA3')
